# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
kickstarter = pd.read_csv("./Kickstarter_projects_Feb19.csv")

kickstarter.head(100)
# Out:
#             id                                               name currency  \
# 0   1687733153              Socks of Speed and Socks of Elvenkind      USD
# 1    227936657   Power Punch Boot Camp: An All-Ages Graphic Novel      GBP
# 2    454186436         Live Printing with SX8: "Squeegee Pulp Up"      USD
# 3    629469071                  Lost Dog Street Band's Next Album      USD
# 4    183973060                              Qto-X, a Tiny Lantern      USD
# 5    122409435                        Aaron McDonnell EP "Follow"      USD
# 6    421029848                                          Lush Life      USD
# 7   1452339343  The biggest NASA fashion collection in the gal...      EUR
# 8    815131323                                    The Nothing Box      USD
# 9   2132215273  "Sittin' 'round waitin' for the world to end" ...      USD
# 10      390870                      Those White Horses - Issue #1      CAD
# ...

# %%
kickstarter.shape
# Out:
# (192548, 20)

# %%
kickstarter.columns
# Out:
# Index(['id', 'name', 'currency', 'main_category', 'sub_category',
#        'launched_at', 'deadline', 'duration', 'goal_usd', 'city', 'state',
#        'country', 'blurb_length', 'name_length', 'status', 'start_month',
#        'end_month', 'start_Q', 'end_Q', 'usd_pledged'],
#       dtype='object')

# %%
kickstarter['main_category'].value_counts()
# Out:
# music           25850
# film & video    25622
# technology      19592
# art             19043
# publishing      18676
# food            14961
# games           12567
# fashion         10812
# comics           8168
# design           7719
# photography      7346
# crafts           6530
# theater          6451
# journalism       5287
# dance            3924
# Name: main_category, dtype: int64

# %%
kickstarter['country'].value_counts()
# Out:
# US    137845
# GB     21200
# CA      8872
# AU      4373
# DE      3020
# FR      2376
# IT      2045
# MX      2026
# ES      1684
# NL      1651
# SE      1275
# HK       941
# NZ       842
# DK       826
# SG       634
# CH       596
# IE       581
# BE       493
# AT       449
# NO       448
# JP       317
# LU        54
# Name: country, dtype: int64

# %%
kickstarter.duration.value_counts()
# Out:
# 30.0    86776
# 60.0    14363
# 45.0     7505
# 31.0     6861
# 35.0     4980
# 40.0     4521
# 21.0     4459
# 20.0     4257
# 32.0     3682
# 25.0     3622
# 28.0     3615
# 29.0     3495
# 15.0     3409
# 14.0     3048
# 33.0     2892
# 34.0     1876
# 27.0     1720
# 22.0     1700
# 36.0     1654
# 10.0     1533
# 23.0     1515
# 24.0     1511
# 26.0     1476
# 7.0      1317
# 37.0     1285
# 50.0     1138
# 18.0     1063
# 38.0     1032
# 16.0      990
# 59.0      913
#         ...
# 89.0       41
# 62.0       28
# 66.0       16
# 88.0       15
# 70.0       15
# 74.0       12
# 76.0       11
# 84.0       11
# 87.0       11
# 71.0       11
# 64.0       10
# 75.0       10
# 81.0        9
# 69.0        9
# 63.0        9
# 80.0        9
# 65.0        9
# 77.0        9
# 67.0        8
# 86.0        8
# 85.0        8
# 82.0        6
# 68.0        6
# 78.0        6
# 72.0        5
# 79.0        4
# 73.0        3
# 93.0        2
# 92.0        2
# 83.0        1
# ...

# %%
kickstarter.status.value_counts()
# Out:
# successful    117307
# failed         75241
# Name: status, dtype: int64

# %%
kickstarter.start_month.value_counts()
# Out:
# 10    18155
# 7     17944
# 11    17294
# 5     16997
# 8     16622
# 6     16622
# 9     16554
# 3     16552
# 4     15833
# 1     14504
# 2     14331
# 12    11140
# Name: start_month, dtype: int64

# %%
kickstarter['money']=kickstarter['usd_pledged']-kickstarter['goal_usd']

kickstarter.head(10)
# Out:
#            id                                               name currency  \
# 0  1687733153              Socks of Speed and Socks of Elvenkind      USD
# 1   227936657   Power Punch Boot Camp: An All-Ages Graphic Novel      GBP
# 2   454186436         Live Printing with SX8: "Squeegee Pulp Up"      USD
# 3   629469071                  Lost Dog Street Band's Next Album      USD
# 4   183973060                              Qto-X, a Tiny Lantern      USD
# 5   122409435                        Aaron McDonnell EP "Follow"      USD
# 6   421029848                                          Lush Life      USD
# 7  1452339343  The biggest NASA fashion collection in the gal...      EUR
# 8   815131323                                    The Nothing Box      USD
# 9  2132215273  "Sittin' 'round waitin' for the world to end" ...      USD
#
#   main_category    sub_category          launched_at             deadline  \
# 0         games  Tabletop Games  2018-10-30 20:00:02  2018-11-15 17:59:00
# ...

# %%
kickstarter[kickstarter['money']<0]
# Out:
#                 id                                               name  \
# 197      293587340  Make Kit - Healthy Recipe Packs - Stretch Goal...
# 321      436382110  TAPIOCA - South American Street Food & CachaÃ...
# 394     1958497854                 Handmade Crochet Baby Clothing Set
# 680      731715907                                 Palacios de Bronce
# 775      426106201  Innerpreneurship // Book // Working Your Life ...
# 911     1564357583                                        SERIE ALTER
# 1008     100078996  APP - CUSTOM SHOES/ Calzado Personalizado - MA...
# 1207     515198469         Simon Blood ''The Seventh Moon '' Volume I
# 1388     379285236                     Mi nombre es Berenice Macotela
# 1702    2043055572                             'Febrero' Cortometraje
# 1872    1553165043                                       Show or Tell
# 2044     851336731        PLATINUM 78: SLIM-LINE WALLET / CARD HOLDER
# ...

# %%
kickstarter.goal_usd.mean()
# Out:
# 37049.903912993315

# %%
kickstarter.goal_usd.min()
# Out:
# 0.01

# %%
kickstarter.goal_usd.max()
# Out:
# 129033257.0

# %%
kickstarter_usd = kickstarter[['usd_pledged']]

kickstarter_usd.boxplot();

# %%
kickstarter.boxplot(column="usd_pledged")

# %%
kickstarter_category = kickstarter['main_category'].value_counts()

kickstarter_category.plot(kind = 'bar');

# %%
kickstarter_types= kickstarter.groupby(by=["main_category"]).agg({"goal_usd":['sum'],"usd_pledged":["sum"]})
kickstarter_types.plot.bar();

# %%
plt.figure(figsize=(16,5))

plt.subplot(1, 2, 1)
kickstarter_types.plot.bar();

plt.subplot(1, 2, 2)
kickstarter_category.plot(kind = 'bar');

# %%
kickstarter['usd_pledged'].corr(kickstarter['duration'])
# Out:
# 0.025177485787004232

# %%
kickstarter.corr()
# Out:
#                     id  duration  goal_usd  blurb_length  name_length  \
# id            1.000000  0.003787  0.001370     -0.000418    -0.007221
# duration      0.003787  1.000000  0.026188      0.031181    -0.016826
# goal_usd      0.001370  0.026188  1.000000     -0.002095    -0.005263
# blurb_length -0.000418  0.031181 -0.002095      1.000000     0.136685
# name_length  -0.007221 -0.016826 -0.005263      0.136685     1.000000
# start_month  -0.000726  0.007794  0.002996     -0.039289     0.011408
# end_month    -0.001530 -0.026497  0.000176     -0.029991     0.018236
# usd_pledged  -0.002153  0.025177  0.007992     -0.007005     0.052457
# money        -0.001553 -0.023907 -0.996179      0.001477     0.009828
#
#               start_month  end_month  usd_pledged     money
# id              -0.000726  -0.001530    -0.002153 -0.001553
# duration         0.007794  -0.026497     0.025177 -0.023907
# goal_usd         0.002996   0.000176     0.007992 -0.996179
# ...

# %%
kickstarter.corr(method = 'spearman')
# Out:
#                     id  duration  goal_usd  blurb_length  name_length  \
# id            1.000000  0.004743 -0.000552      0.000177    -0.007212
# duration      0.004743  1.000000  0.243695      0.027187     0.001608
# goal_usd     -0.000552  0.243695  1.000000      0.014198     0.045251
# blurb_length  0.000177  0.027187  0.014198      1.000000     0.114026
# name_length  -0.007212  0.001608  0.045251      0.114026     1.000000
# start_month  -0.000789  0.012403  0.023180     -0.035946     0.011405
# end_month    -0.001559 -0.021266  0.028005     -0.027530     0.018649
# usd_pledged  -0.002478  0.023037  0.295882     -0.053103     0.214097
# money        -0.003178 -0.100009 -0.169818     -0.058555     0.174013
#
#               start_month  end_month  usd_pledged     money
# id              -0.000789  -0.001559    -0.002478 -0.003178
# duration         0.012403  -0.021266     0.023037 -0.100009
# goal_usd         0.023180   0.028005     0.295882 -0.169818
# ...

# %%
kickstarter_country = kickstarter['country'].value_counts()

kickstarter_country.plot(kind = 'bar');

# %%
plt.scatter(kickstarter.duration,kickstarter.usd_pledged, alpha=0.5);

# %%
kickstarter_month = kickstarter[["start_month"]]

kickstarter_month.columns

#sns.lineplot(x="start_month", y="object" ,data=kickstarter_month)
# Out:
# Index(['start_month'], dtype='object')

# %%
kickstarter_month = kickstarter.groupby(by='start_month').agg({'usd_pledged':['sum']})

kickstarter_month.plot(kind = 'line', style='.-')
plt.legend(loc='best', bbox_to_anchor=(1.0, 0.5));

# %%
sns.pairplot(kickstarter);

# %%
kickstarter['duration'].hist();
